# %% [markdown]
# # Lab 04 - Sampling, Nyquist, Eye Diagrams, PR Signaling
#
# ### Maurice Woods
#
# ### 17 February 2017

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------
# # Note to the reader/grader:
#
# The tardiness of this lab was a result of several factors, namely the fact that past code written for the past 3 labs was written in a fragile and relatively naive way. As a result, it took quite some time to revise and sometimes rewrite the code necessary to run the functions used in this lab (including an installation error with Jupyter Notebook which required 3 reinstalls of my Linux Virtual Machine before the error was found; DON'T USE ANACONDA...) x_x
#
# While I understand that there are penatlies for my tardiness, I hope that the increased stability of my code and the subsequent robustness for this code's use in later labs will show through the quality of my work here and in future labs. Thank you for taking this into account when reviewing this lab.
#
# -Maurice

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------
# ## EC 01 - Sampling  Theorem,  and  PAM  with  Manchester  and 'RCf' p(t)

# %%
from pylab import *
import ecen4652 as ecen
import pamfun
import showfun
import quick
from ascfun import asc2bin

# %% [markdown]
# ##### Part A) - Build the GRC flowgraph for the visualization of the sampling theorem given in the introduction (f0=2700Hz)

# %% [markdown]
# Observe the reconstructed ‘CT’ waveform and explain why it does not have a frequency of 2700 Hz
#
# > Cosine Wave; f0 = 1000Hz
# > ![1A.1](E1_A_1.png)
# >
# > Cosine Wave; f0 = 2700Hz
# > ![1A.2](E1_A_2.png)
# >
# > Reconstructed sine wave does not have a frequency of f0 (2700Hz) because this input frequency is larger than the maximum frequency allowed to satisfy Nyquist criteria for a sampling rate of Fs2/2 = 4000/2 = 2000Hz; Any f0 greater than 2000Hz will not be correctly reconstructed due to the violation of Nyquist's criteria.

# %% [markdown]
# ---------------------
# ##### Part B) - Input a 1000 Hz square wave into the flowgraph of Part A)

# %%
# Thing

# %% [markdown]
# Does the  reconstructed  ‘CT’  waveform  at  the  output  look  as  expected? Explain!
#
# > Square Wave; f0 = 1000Hz
# > ![1B.1](E1_B_1.png)
# >
# > The reconstructed waveform is no longer a square wave but a cosine wave of the same frequency as the input square wave. This is to be expected as the interpolation is using a sinc pulse to reconstruct the square wave. We can see that the reconstructed wave is actually taller than the original wave because the sinc is interpolating a peak _in between_ the two corner peaks of the square wave.
#
# Change the frequency of the square wave to 1200 Hz. Explain the reconstructed waveform that you see
# using explanations in both the time and frequency domains
#
# > Square Wave; f0 = 1200Hz
# > ![1B.2](E1_B_2.png)
# >
# > Now everything is busted...the Nyquist criteria is violated AND the square wave is being interpolated by a sinc pulse of inadequate resolution.

# %% [markdown]
# -----
# ##### Part C) - Build  the  GRC  flowgraph  that  uses  a  bandpass  filter  for  the  ‘CT’  waveform  reconstruction
#
# > ![1C.1](E1_C_1.png)
# >
# > ![1C.2](E1_C_2.png)
#
# Verify that input and output ‘CT’ waveforms are identical.
#
# > ![1C.3](E1_C_3.png)
# > As seen above, the input and output waveforms ARE identical

# %% [markdown]
# -----
# ##### Part D) - Extend the pam10 function in the pamfun module to include the RCf pulse with rolloff parameter α and  truncation  index k and  the manchester or diphase pulse

# %%
Fb = 350 # Baud rate (bits/sec)
Fs = 44100 # Sampling frequency (samples/sec)

string="Test"
dn = asc2bin(string,8)
dn = multiply(dn,2)-1

sig_pt = ecen.sigSequ(dn,Fb)

# %%
pam_pt = pamfun.pam11(sig_pt,Fs,'man',[])

# %%
pam_pt = pamfun.pam11(sig_pt,Fs,'rcf',[4,0.4])
# Out:
# /home/maurice/Documents/Git/CUBoulderMasters/2017spring/CommsLab/Lab04/pamfun.py:171: RuntimeWarning: invalid value encountered in true_divide
#   rcft = divide(rcft_num,float(rcft_den))

# %% [markdown]
# -----
# ##### Part E) -  Generate a  PAM  pulse p(t)  using your pam11 function
#
# Verify that p(t) and P(f) look right for the manchester and the RCf pulses that you added to the pam11 function.

# %%
from pylab import *
import ecen4652 as ecen
import pamfun
import showfun

Fs = 44100   #Sampling rate
FB = 350   #Baud rate
N = FB   #Number of symbols
an = hstack((zeros(round(N/2)), 1, zeros(round(N/2)-1)))   #Single pulse, padded with zeros
sig_an = ecen.sigSequ(an, FB, 0)

# %%
### Manchester Pulse
ptype = 'man'
pparms = []
plotparms = ['middle',20]
sig_pt = pamfun.pam11(sig_an,Fs,ptype,pparms,plotparms) #Generate PAM pulse
sig_pt.set_t0(-(N/2)/float(FB))   #Place center of pulse at t=0

ff_parms = [-600,600,-60] 
showfun.showft(sig_pt,ff_parms) #Plot FT of pulse

# %% [markdown]
# > Based on the FT of the Manchester pulse above and comparing it to the Manchester pulse shown in the lab introduction, we see that our pulse does, in fact, match the expected pulse shape (in time AND in frequency)

# %%
### RCf Pulse
ptype = 'rcf'
pparms = [4,0.4]
plotparms = ['middle',20]
sig_pt = pamfun.pam11(sig_an,Fs,ptype,pparms,plotparms) #Generate PAM pulse
sig_pt.set_t0(-(N/2)/float(FB))   #Place center of pulse at t=0


ff_parms = [-600,600,-60] 
showfun.showft(sig_pt,ff_parms) #Plot FT of pulse
# Out:
# /home/maurice/Documents/Git/CUBoulderMasters/2017spring/CommsLab/Lab04/pamfun.py:171: RuntimeWarning: invalid value encountered in true_divide
#   rcft = divide(rcft_num,float(rcft_den))

# %% [markdown]
# > Based on the FT of the RCf above and comparing it to the RCf shown in the lab introduction, we see that our pulse does, in fact, match the expected pulse shape (in time AND in frequency)

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------------------------------------------
# ## EC 02 -  PAM Analysis with Eye Diagrams
#
# ##### Part A) - Write a Python function, called showeye that can be used to display eye diagrams of digital PAM signals

# %%
from pylab import *
import pamfun
import showfun
import ecen4652 as ecen
Fs = 44100                     # Sampling rate
FB = 200                       # Baud rate
NTd = 50                       # Number of traces displayed
N = NTd+10                     # Number of data symbols
L = 4                          # Number of data levels
dly = 0.5                      # Trigger delay TB/2

dn = floor(L*rand(N))          # Unipolar L-level random data
an = 2*dn - (L-1)              # Polar L-level DT sequence
sig_an = ecen.sigSequ(an,FB)
antt = quick.quicktt(sig_an.sig,FB)

intrp_an = pamfun.pam10(sig_an,Fs,'sinc', [3, 4])# int(Fs/FB)]) # PAM signal, ’sinc’ p(t)
intrp_antt = quick.quicktt(intrp_an.sig,intrp_an.Fs)

quick.quickplot(intrp_antt,intrp_an.sig,'b',antt,sig_an.sig,'or',"Random 4-Level Sequence [red 'o'] and 4x 'sinc' Interpolation [blue-]",'Time (s)', 'Data Level',[],[15,6])

wave_an = ecen.sigWave(intrp_an.sig, intrp_an.Fs, 0)
showfun.showeye(wave_an, FB, NTd, [dly, 3, -1.5*L, 1.5*L])

# %% [markdown]
# ##### Part B) -  Find out as much as possible about the pamsig401.wav and pamsig402.wav PAM signals.  In particular, try to find FB, p(t), and the number of levels L.  Also, try to characterize channel impairments (if any) like ISI, noise, and timing jitter

# %%
from wavfun import wavread
[seq, framerate] = wavread("pamsig401.wav")

Fs=framerate

seqtt = quick.quicktt(seq,Fs)
quick.quickplot(seqtt[0:5000],seq[0:5000],'-b',[],[],'','','','',[],[15,8])

# %% [markdown]
# > This waveform appears to have a baud rate of ~1bit/0.002sec and looks binary.
#
# > If we search around this value by manually tweeking FB, we find...

# %%
wave_an = ecen.sigWave(seq, Fs, 0)

### Make an array of FBs over which we can 'scan' for a good eye diagram
#FBden=arange(0.0015,0.0035,0.00001)
#FBnum=ones(len(FBden))
#FB=divide(FBnum,FBden)
#showfun.showeye(wave_an, FB, NTd, [dly, 3, -1.5*L, 1.5*L])
#sshowfun.showft(wave_an,[-2000, 2000, -60])

FB=359.712230216
showfun.showeye(wave_an, FB, NTd, [dly, 3, -1.5*L, 1.5*L])
showfun.showft(wave_an,[-2000, 2000, -60])

# %% [markdown]
# > There are no GREAT eye diagrams produced from any reasonable FB precision. The BEST eye diagram found to 0.00001Hz precision is FB=359.712230216bps. With the eye diagram (shown above), we confirm that the data appears to only use two levels (binary) and seems to suffer some time jitter (as evidenced by what appears to be a horizontal shift in some traces). Also, based on the FT, the interpolation used may be an RCf function, as the FT for this plot and that of the single pulse in part E1.e  show a similar pattern

# %%
[seq, framerate] = wavread("pamsig402.wav")

Fs=framerate

seqtt = quick.quicktt(seq,Fs)  # [0:10000]
quick.quickplot(seqtt,seq,'-b',[],[],'','Data from pamsig402.wav','Time (s)','Magnitude',['first',10000],[15,8])

# %% [markdown]
# > The waveform appears to have a baudrate of ~10bit/0.05sec and appears to use at least 5 data levels
#
# > If we search around this FB by tweeking the value manually...

# %%
wave_an = ecen.sigWave(seq, Fs, 0, 'sinc-Interpolated, Random Data')
FB=10/0.0475

showfun.showeye(wave_an, FB, NTd, [dly, 3, -1.5*L, 1.5*L])
showfun.showft(wave_an,[-200, 200, -60])

# %% [markdown]
# > We can very clearly see that the data has 5 distinct levels and, from our seccessful plot, we can see that FB=10bit/0.0475sec=210.52631578947367bits/sec and has little time jitter. Again, the interpolator used was likely an RCf pulse, as the FT of this plot and that of the single pulse used in E1.e are similar

# %% [markdown]
# ##### Part C) - Use scipy.signal.butter  to  compute the numerator and the denominator polynomial coefficients of the rational transfer function H(z) of an N-th order DT Butterworth filter

# %%
[seq_1, framerate] = wavread("pamsig403_rcvr_1.wav")
[seq_2, framerate] = wavread("pamsig403_rcvr_2.wav")
[seq_3, framerate] = wavread("pamsig403_rcvr_3.wav")
[seq_4, framerate] = wavread("pamsig403_rcvr_4.wav")

Fs=framerate
seqtt = quick.quicktt(seq_1,Fs)

quick.quickplot(seqtt,seq_1,'-b',[],[],'','"pamsig403_rcvr_1.wav" at fL=0.25*FB','Time (s)','Magnitude',['first',20000],[15,4])
quick.quickplot(seqtt,seq_2,'-b',[],[],'','"pamsig403_rcvr_2.wav" at fL=0.50*FB','Time (s)','Magnitude',['first',20000],[15,4])
quick.quickplot(seqtt,seq_3,'-b',[],[],'','"pamsig403_rcvr_3.wav" at fL=1.00*FB','Time (s)','Magnitude',['first',20000],[15,4])
quick.quickplot(seqtt,seq_4,'-b',[],[],'','"pamsig403_rcvr_4.wav" at fL=2.00*FB','Time (s)','Magnitude',['first',20000],[15,4])

# %%
FB=100

wave_an_1 = ecen.sigWave(seq_1, Fs, 0, 'pamsig403_rcvr_1.wav (fL=0.25xFB)')
wave_an_2 = ecen.sigWave(seq_2, Fs, 0, 'pamsig403_rcvr_2.wav (fL=0.50xFB)')
wave_an_3 = ecen.sigWave(seq_3, Fs, 0, 'pamsig403_rcvr_3.wav (fL=1.00xFB)')
wave_an_4 = ecen.sigWave(seq_4, Fs, 0, 'pamsig403_rcvr_4.wav (fL=2.00xFB)')

showfun.showeye(wave_an_1, FB, NTd, [dly, 3, -1.5*L, 1.5*L],'small')
showfun.showeye(wave_an_2, FB, NTd, [dly, 3, -1.5*L, 1.5*L],'small')
showfun.showeye(wave_an_3, FB, NTd, [dly, 3, -1.5*L, 1.5*L],'small')
showfun.showeye(wave_an_4, FB, NTd, [dly, 3, -1.5*L, 1.5*L],'small')

# %% [markdown]
# What can you conclude for the channel bandwidth that is needed for reliable detection of the transmitted data?
#
# > For reasonable data level detection sensitivity, fL=0.5xFB will suffice.
#
# Look at the eye diagram below that was obtained using the GNU Radio flowgraph of this experiment.  Can you determine the N and the fL that was used for the Butterworth filter?

# %% [markdown]
# > To test the theories I use to deduce N and fL below, I tested three more outputs of the "pamsig403_test_001" GNU Radio flowgraph:
# > - A very high fL (fL=10) to see the exagerated effects of large fL values (the small fL values were already explored above)
# > - A very high N (N=9) and a very low N (N=0) to see the exagerated effects of extreme N values
#
# > ![2C.1](E2_C_1.png)
#
# > As we can see from these extra plots, low N's create the desired "flatness" ont eh top and bottom of the traces of the eye diagram and lower fL's create the slow, curved transitions (rather than steep, vertical transitions with high fL's).
#
# > All of these things considered: The eye diagram shown in the lab appears to have used a very low N (since the tops/bottoms of the trace boundaries are very flat) and a relatively low fL (to match the sloped curves of the level transitions)
#
# > ![2C.2](E2_C_2.png)
#
# > This eye diagram is nearly identical to the diagram in the lab and uses fL=0.5xFB and N=1
